# %%
from wimprates_ansh import *
m_MeV = 10
sigmaE = 1e-36
fdm = 2


drs = dRdE(m_MeV,sigmaE,fdm,e_er = None,isoangle = 0,mat = 'Xe',useVerne = False,verbose=False,integrate=False)
plot_dRdE(drs,m_MeV,sigmaE,e_er=None,mat= 'Xe',lnE = False,plotTotal = False,day=True)

drs = dRdE(m_MeV,sigmaE,fdm,e_er = None,isoangle = 9,mat = 'Xe',useVerne = False,verbose=False,integrate=False)
plot_dRdE(drs,m_MeV,sigmaE,e_er=None,mat= 'Xe',lnE = False,plotTotal = False,day=True)

drs = dRdE(m_MeV,sigmaE,fdm,e_er = None,isoangle = 18,mat = 'Xe',useVerne = False,verbose=False,integrate=False)
plot_dRdE(drs,m_MeV,sigmaE,e_er=None,mat= 'Xe',lnE = False,plotTotal = False,day=True)


drs = dRdE(m_MeV,sigmaE,fdm,e_er = None,isoangle = 24,mat = 'Xe',useVerne = False,verbose=False,integrate=False)
plot_dRdE(drs,m_MeV,sigmaE,e_er=None,mat= 'Xe',lnE = False,plotTotal = False,day=True)

drs = dRdE(m_MeV,sigmaE,fdm,e_er = None,isoangle = 35,mat = 'Xe',useVerne = False,verbose=False,integrate=False)
plot_dRdE(drs,m_MeV,sigmaE,e_er=None,mat= 'Xe',lnE = False,plotTotal = False,day=True)

# %%
from wimprates_ansh import *


m_MeV = 1000
sigmaE = 1e-36
fdm = 0
n_el, drsn = dRdne(m_MeV,sigmaE,fdm,e_er = None,isoangle=0,material='Xe',maxne = 16,ne='All',return_shells=True,useVerne=True,verbose=False,integrate=False)
plot_dRdne(n_el,drsn,m_MeV,sigmaE,fdm,tonyear=True,day =False)
n_el, drsn = dRdne(m_MeV,sigmaE,fdm,e_er = None,isoangle=35,material='Xe',maxne = 16,ne='All',return_shells=True,useVerne=True,verbose=False,integrate=False)
plot_dRdne(n_el,drsn,m_MeV,sigmaE,fdm,tonyear=True,day =False)

# %%
from wimprates_ansh import *

for FDMn in [0,2]:
    for mat in ['Xe','Ar']:
        for useVerne in [False]:
            generate_modulated_wimprates(FDMn,useVerne = useVerne,overwrite=True,material=mat,integrate=False)
# Out:
# ...
#   0%|          | 0/602 [00:00<?, ?it/s]
